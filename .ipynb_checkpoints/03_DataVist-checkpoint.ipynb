# %% [markdown]
# # Introduction
# Integrate the data from actor and actress

# %% [markdown]
# ## Imports

# %%
# Data manipulation
import pandas as pd
import numpy as np
import seaborn  as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
#import nltk

# %%
#import pandas as pd
df = pd.read_csv('export_df_all_divorce_dropna.csv')

# %% [markdown]
# ### data

# %%
df = df.drop(["Unnamed: 0"], axis = 1)
df.head()
# Out:
#             name        bday  \
# 0   Willie Aames  1960-07-15
# 1   Bruce Abbott  1954-07-28
# 2     Bud Abbott         NaN
# 3  Philip Abbott         NaN
# 4      Jake Abel  1987-11-18
#
#                                              name_sp num_of_child education  \
# 0  Vicki Weatherman ( m.  1979–1984) Maylo McCasl...            2       NaN
# 1  Linda Hamilton ( m.  1982;  div.  1989) Kathle...            2       NaN
# 2                            Betty Smith ( m.  1918)            2       NaN
# 3                     Jane Dufrayne ( m.  1950–1998)          NaN       NaN
# 4                             Allie Wood ( m.  2013)          NaN       NaN
#
#                                                 role  \
# 0  Actor, director, television producer, screenwr...
# 1                                              Actor
# 2                          Actor, comedian, producer
# 3                                              Actor
# 4                               Model, actor, singer
#
#                         birthplace     bday_sp              birthplace_sp  \
# 0  Newport Beach, California, U.S.         NaN                        NaN
# 1           Portland, Oregon, U.S.  1956-09-26  Salisbury, Maryland, U.S.
# 2    Asbury Park, New Jersey, U.S.         NaN                        NaN
# 3          Lincoln, Nebraska, U.S.         NaN                        NaN
# 4               Canton, Ohio, U.S.         NaN                        NaN
#
#    role_sp  ... sex divorce  year_m_1  year_div_1  year_m_sp_1 year_div_sp_1  \
# 0      NaN  ...   M     1.0    1979.0         NaN          NaN           NaN
# 1  Actress  ...   M     1.0    1982.0      1989.0       1982.0        1982.0
# 2      NaN  ...   M     0.0    1918.0         NaN          NaN           NaN
# 3      NaN  ...   M     1.0    1950.0         NaN          NaN           NaN
# 4      NaN  ...   M     0.0    2013.0         NaN          NaN           NaN
#
#   age_m_1 age_div_1 age_m_sp_1 age_div_sp_1
# 0    19.0       NaN        NaN          NaN
# 1    28.0      35.0       26.0         26.0
# 2     NaN       NaN        NaN          NaN
# 3     NaN       NaN        NaN          NaN
# 4    26.0       NaN        NaN          NaN
#
# [5 rows x 44 columns]

# %%
df.columns
# Out:
# Index(['name', 'bday', 'name_sp', 'num_of_child', 'education', 'role',
#        'birthplace', 'bday_sp', 'birthplace_sp', 'role_sp', 'name_sp_sp',
#        'num_of_child_sp', 'age_diff', 'age', 'age_spouse', 'name_sp_cl',
#        'year_m', 'year_div', 'name_sp_sp_cl', 'year_m_sp', 'year_div_sp',
#        'num_of_child_cl', 'num_of_child_sp_cl', 'name_sp_cl.1', 'num_of_m',
#        'name_sp_sp_cl.1', 'num_of_m_sp', 'num_of_role', 'num_of_role_sp',
#        'geohash', 'geohash_sp', 'geo_distance', 'zodiac', 'zodiac_sp', 'sex',
#        'divorce', 'year_m_1', 'year_div_1', 'year_m_sp_1', 'year_div_sp_1',
#        'age_m_1', 'age_div_1', 'age_m_sp_1', 'age_div_sp_1'],
#       dtype='object')

# %%
df.shape
# Out:
# (3090, 44)

# %%
####

# %%
#fig = plt.figure(figsize = (15,20))
#ax = fig.gca()
df.hist(figsize=(15,12));

# %%
df_new = df[['name','bday','sex','age','age_diff', 'zodiac', 
          'zodiac_sp','num_of_m', 'num_of_m_sp', 
          'num_of_child_cl', 'num_of_child_sp_cl', 
          'num_of_role', 'num_of_role_sp', 
          'geohash', 'geo_distance', 
          'age_m_1', 'age_div_1', 'age_m_sp_1', 'age_div_sp_1', 
          'divorce']]

fig, ax = plt.subplots(figsize=(12,12))         # Sample figsize in inches
sns.heatmap(df_new.corr(), annot=True, fmt=".2f");

# %% [markdown]
# calculate divorce rate

# %%
# calculate the divorce rate
a = (df[df['divorce']==1]['divorce'].sum())/(df['divorce'].notnull().sum())*100

"overall divorce rate = {0:8.2f} %".format(a)#
# Out:
# 'overall divorce rate =    53.95 %'

# %%
a = df[(df['sex']=='M') & (df['divorce']==1)]['divorce'].sum()/(df[df['sex']=='M']['divorce'].notnull().sum())*100
"overall divorce rate for male = {0:8.2f} %".format(a)#
# Out:
# 'overall divorce rate for male =    49.55 %'

# %%
a = df[(df['sex']=='F') & (df['divorce']==1)]['divorce'].sum()/(df[df['sex']=='F']['divorce'].notnull().sum())*100
"overall divorce rate for female = {0:8.2f} %".format(a)#
# Out:
# 'overall divorce rate for female =    62.11 %'

# %%
# Set up a factorplot
g = sns.factorplot("sex", "divorce", data=df, kind="bar", palette="muted", legend=False)
                   
# Show plot
plt.show()

# %%
# calculate the divorce rate
(df['divorce'].value_counts()/df['divorce'].notnull().sum()).plot(kind="bar")
plt.title("divoice rate (include male and female)");

# %%
#sns.distplot('age', data = df)
sns.jointplot(x="num_of_child_cl", y="age_diff", data=df);

# %%
#df_test.shape
#df_test['sex'].hist()
sns.set(style="darkgrid")
ax = sns.countplot(x="sex", data=df1_div_rm)

# %%
df_all_drop_1  = df_test.dropna()#.dropna()
df_all_drop_1.shape
# Out:
# (1243, 11)

# %% [markdown]
# # Conclusions and Next Steps
# Summarize findings here

# %%
import pandas as pd
df = pd.read_csv('export_df_actress.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import test3 as t
import seaborn as sns
# %matplotlib inline

# %%
fill_mean = lambda col: col.fillna(col.mean())
fill_df = drop_sal_df.apply(fill_mean, axis = 0) #Fill all missing values with the mean of the column.

# %%
#Split into explanatory and response variables
X = fill_df[['CareerSatisfaction', 'HoursPerWeek', 'JobSatisfaction', 'StackOverflowSatisfaction']]
y = fill_df['Salary']

#Split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .30, random_state=42) 

lm_model = LinearRegression(normalize=True) # Instantiate
lm_model.fit(X_train, y_train) #Fit
        
#Predict and score the model
y_test_preds = lm_model.predict(X_test) 

#Rsquared and y_test
rsquared_score = r2_score(y_test, y_test_preds)
length_y_test = len(y_test)
"The r-squared score for your model was {} on {} values.".format(rsquared_score, length_y_test)

# %%
pd.get_dummies(dummy_var_df['col1'])
