# %% [markdown]
# # Introduction
# Integrate the data from actor and actress

# %% [markdown]
# ### Imports
# Import libraries and write settings here.

# %%
# Data manipulation
import pandas as pd
import numpy as np
import seaborn  as sns
import matplotlib.pyplot as plt
from time import gmtime, strftime
# %matplotlib inline
#import nltk

# %%
#import pandas as pd
df_actress = pd.read_csv('export_df_actress_div.csv')
df_actor = pd.read_csv('export_df_actor_div.csv')

# %% [markdown]
# Merge two datasets

# %%
df = df_actor.append(df_actress, ignore_index=True, sort=False)
df.head()
# Out:
#    Unnamed: 0           name        bday  \
# 0           0        50 Cent  1975-07-06
# 1           1      Lee Aaker  1943-09-25
# 2           2   Willie Aames  1960-07-15
# 3           3  Quinton Aaron  1984-08-15
# 4           4   Victor Aaron  1956-09-11
#
#                                              name_sp num_of_child education  \
# 0  \n G-Unit \n Dr. Dre \n Eminem \n The Game \n ...            2       NaN
# 1           Sharon Ann Hamilton (1969-71) (divorced)          NaN       NaN
# 2  Vicki Weatherman ( m.  1979–1984) Maylo McCasl...            2       NaN
# 3                                                NaN          NaN       NaN
# 4              Eduvina Matta (m. 1974–1984) divorced            2       NaN
#
#                                                 role  \
# 0  \nRapper\nsinger\nsongwriter\nactor\nentrepren...
# 1         Actor, producer, carpenter, ski instructor
# 2  Actor, director, television producer, screenwr...
# 3                                              Actor
# 4                                 Actor, voice actor
#
#                         birthplace bday_sp birthplace_sp   ...   num_of_m_sp  \
# 0    New York City, New York, U.S.     NaN           NaN   ...           NaN
# 1    Los Angeles, California, U.S.     NaN           NaN   ...           NaN
# 2  Newport Beach, California, U.S.     NaN           NaN   ...           NaN
# 3        The Bronx, New York, U.S.     NaN           NaN   ...           NaN
# 4              Odessa, Texas, U.S.     NaN           NaN   ...           NaN
#
#   num_of_role num_of_role_sp  geohash  geohash_sp  geo_distance  zodiac  \
# 0         8.0            NaN  dr5regw         NaN            NaN    6.0
# 1         5.0            NaN  9q5ctr1         NaN            NaN    9.0
# 2         5.0            NaN  9mupk2n         NaN            NaN    6.0
# 3         1.0            NaN  dr72r5t         NaN            NaN    7.0
# 4         3.0            NaN  9txjnt6         NaN            NaN    8.0
#
#   zodiac_sp sex divorce
# 0       NaN   M     NaN
# 1       NaN   M     NaN
# 2       NaN   M     1.0
# 3       NaN   M     NaN
# 4       NaN   M     NaN
#
# [5 rows x 37 columns]

# %%
df.to_csv('export_df_all_div.csv', header=True)

# %% [markdown]
# ### Clean the dataset
# remove the following columns
# Unnamed: 0

# %%
# check the missing value
(df.isnull().sum()*100 / len(df)).sort_values()
# Out:
# Unnamed: 0             0.000000
# sex                    0.000000
# name                   0.048309
# birthplace             4.412238
# geohash                4.593398
# role                   8.904992
# num_of_role            8.904992
# bday                  10.342190
# zodiac                10.342190
# age                   10.342190
# name_sp               49.661836
# num_of_child          68.260870
# num_of_m              72.995169
# name_sp_cl.1          72.995169
# name_sp_cl            72.995169
# divorce               72.995169
# year_m                73.079710
# num_of_child_cl       73.929147
# year_div              88.502415
# name_sp_sp            90.962158
# birthplace_sp         91.058776
# geohash_sp            91.070853
# geo_distance          91.119163
# zodiac_sp             91.441224
# bday_sp               91.441224
# age_spouse            91.441224
# num_of_role_sp        91.590177
# age_diff              91.590177
# role_sp               91.590177
# education             91.731079
# name_sp_sp_cl         92.391304
# num_of_m_sp           92.391304
# name_sp_sp_cl.1       92.391304
# year_m_sp             92.463768
# num_of_child_sp       93.107890
# num_of_child_sp_cl    94.118357
# year_div_sp           95.785024
# dtype: float64

# %% [markdown]
# ### More preprocessing work
# Calcualte the year of first marrage and first divoice

# %%
# first year of marrage
year_m_1 = []
for i in range(len(df)):
    try: 
        year_m_1.append(literal_eval(df['year_m'][i])[0])
    except:
        year_m_1.append(np.nan)

# %%
# first year of divoice
year_div_1 = []
for i in range(len(df)):
    try: 
        year_div_1.append(literal_eval(df['year_div'][i])[0])
    except:
        year_div_1.append(np.nan)

# %%
# first year of marrage (their spouse)
year_m_sp_1 = []
for i in range(len(df)):
    try: 
        year_m_sp_1.append(literal_eval(df['year_m_sp'][i])[0])
    except:
        year_m_sp_1.append(np.nan)

# %%
# first year of divoice (their spouse)
year_div_sp_1 = []
for i in range(len(df)):
    try: 
        year_div_sp_1.append(literal_eval(df['year_div_sp'][i])[0])
    except:
        year_div_sp_1.append(np.nan)

# %%
df = df.drop(['year_m_1', 'year_div_1', 'year_m_sp_1', 'year_div_sp_1'], axis =1)

# %%
df_year_m_1  = pd.DataFrame({'year_m_1':year_m_1 })#.fillna(0).astype(int).replace({0:np.nan})
df_year_div_1  = pd.DataFrame({'year_div_1':year_div_1 })#.fillna(0).astype(int).replace({0:np.nan})
df_year_m_sp_1  = pd.DataFrame({'year_m_sp_1':year_m_sp_1 })#.fillna(0).astype(int).replace({0:np.nan})
df_year_div_sp_1  = pd.DataFrame({'year_div_sp_1':year_m_sp_1 })#.fillna(0).astype(int).replace({0:np.nan})
df= pd.concat([df, df_year_m_1, df_year_div_1, df_year_m_sp_1,df_year_div_sp_1], axis=1)

# %% [markdown]
# calculate age of first marrage and first divorce

# %%
#from time import gmtime, strftime
df['age_m_1'] = df['year_m_1'] - df['bday'].dt.year
df['age_div_1']= df['year_div_1'] - df['bday'].dt.year
df['age_m_sp_1']= df['year_m_sp_1']-df['bday_sp'].dt.year
df['age_div_sp_1']= df['year_div_sp_1']-df['bday_sp'].dt.year

# %% [markdown]
# drop the redudant and unclean data

# %%
df = df.drop(['Unnamed: 0', 'education', 'bday_sp'], axis = 1) # drop >90% missing data
df = df.drop(['birthplace', 'birthplace_sp', 'name_sp_cl.1','geohash_sp'], axis = 1) # drop columns that are redundant
df = df.drop(['name_sp', 'num_of_child', 'role', 'role_sp', 'name_sp_sp', 'num_of_child_sp'], axis =1) # drop unclean data
df = df.drop(['name_sp_cl', 'name_sp_sp_cl', 'name_sp_sp_cl.1'], axis =1) # drop unclean data
df = df.drop(['year_m', 'year_div', 'year_m_sp', 'year_div_sp'], axis =1)
df = df.drop(['year_m_1', 'year_div_1', 'year_m_sp_1', 'year_div_sp_1'], axis =1)

# %%
print(df.shape[0])
(df.isnull().sum()*100/len(df)).sort_values()
# Out:
# 24840
# sex                    0.000000
# name                   0.048309
# geohash                4.593398
# num_of_role            8.904992
# bday                  10.342190
# age                   10.342190
# zodiac                10.342190
# num_of_m              72.995169
# divorce               72.995169
# year_m                73.079710
# age_m_1               73.804348
# num_of_child_cl       73.929147
# year_div              88.502415
# age_div_1             88.929147
# geo_distance          91.119163
# age_spouse            91.441224
# zodiac_sp             91.441224
# num_of_role_sp        91.590177
# age_diff              91.590177
# num_of_m_sp           92.391304
# year_m_sp             92.463768
# age_m_sp_1            92.906602
# age_div_sp_1          92.906602
# num_of_child_sp_cl    94.118357
# year_div_sp           95.785024
# dtype: float64

# %% [markdown]
# #### remove outliner

# %%
# fill outliner with nan (negative year)
df.loc[df['age_div_1']<0, ['age_div_1']] = np.nan

# %%
df.sort_values(by=['num_of_m'], ascending=False)
# Out:
#                       name       bday   age_diff         age  age_spouse  \
# 24740          Lana Turner 1921-02-08        NaN   98.238841         NaN
# 24096       Rue McClanahan 1934-02-21        NaN   85.203666         NaN
# 16766         Claude Rains 1889-11-10  -1.848087  129.486574  127.638487
# 6888        Douglas Fowley 1911-05-30        NaN  107.939246         NaN
# 16123         Claude Rains 1889-11-10  -1.848087  129.486574  127.638487
# 16459         Claude Rains 1889-11-10  -1.848087  129.486574  127.638487
# 6752        Douglas Fowley 1911-05-30        NaN  107.939246         NaN
# 16291         Claude Rains 1889-11-10  -1.848087  129.486574  127.638487
# 18570   Billy Bob Thornton 1955-08-04        NaN   63.757640         NaN
# 23339          Arlene Dahl 1925-08-11   6.261593   93.734984   99.996578
# 4425           Tony Curtis 1925-06-03  -2.089023   93.926638   91.837615
# 15728         Claude Rains 1889-11-10  -1.848087  129.486574  127.638487
# 23542       Rhonda Fleming 1923-08-10        NaN   95.739132         NaN
# 18670   Billy Bob Thornton 1955-08-04        NaN   63.757640         NaN
# 24674       Gloria Swanson 1899-03-27  13.985229  120.109242  134.094471
# 15796         Claude Rains 1889-11-10  -1.848087  129.486574  127.638487
# 16627         Claude Rains 1889-11-10  -1.848087  129.486574  127.638487
# 17355        Mickey Rooney 1920-09-23  -2.250560   98.619410   96.368851
# 17188        Mickey Rooney 1920-09-23  -2.250560   98.619410   96.368851
# 15955         Claude Rains 1889-11-10  -1.848087  129.486574  127.638487
# 24692     Elizabeth Taylor 1932-02-27        NaN   87.188649         NaN
# 9083           Don Johnson 1949-12-15        NaN   69.392253         NaN
# 9247           Don Johnson 1949-12-15        NaN   69.392253         NaN
# 9413           Don Johnson 1949-12-15        NaN   69.392253         NaN
# 24366          Jane Powell 1929-04-01        NaN   90.096306         NaN
# 9567           Don Johnson 1949-12-15        NaN   69.392253         NaN
# 9727           Don Johnson 1949-12-15        NaN   69.392253         NaN
# 24470        Ginger Rogers 1911-07-16   9.087113  107.807826  116.894940
# 9899           Don Johnson 1949-12-15        NaN   69.392253         NaN
# 24484       Katharine Ross 1940-01-29        NaN   79.267884         NaN
# ...                    ...        ...        ...         ...         ...
# 24763     Sofia Vassilieva 1992-10-22        NaN   26.535795         NaN
# 24767        Elena Verdugo 1925-04-20        NaN   94.044368         NaN
# 24776       Shawna Waldron 1982-01-25        NaN   37.276604         NaN
# 24780    Quvenzhané Wallis 2003-08-28        NaN   15.688207         NaN
# 24782         Maiara Walsh 1988-02-18        NaN   31.212140         NaN
# 24783      Lisa Ann Walter 1963-08-03        NaN   55.757476         NaN
# 24787         Julie Warner 1965-02-09   6.486102   54.235200   60.721302
# 24788      Jennifer Warren 1941-08-12        NaN   77.731918         NaN
# 24790         Ruth Warrick 1916-06-29        NaN  102.852215         NaN
# 24791     Fredi Washington 1903-12-23        NaN  115.369925         NaN
# 24794  Katherine Waterston 1980-03-03        NaN   39.173973         NaN
# 24796          Carol Wayne 1942-09-06  11.586822   76.664134   88.250957
# 24798           Chloe Webb 1956-06-25        NaN   62.862345         NaN
# 24802         Tahnee Welch 1961-12-26        NaN   57.359152         NaN
# 24806             Mae West 1893-08-17        NaN  125.716476         NaN
# 24807         Celia Weston 1951-12-14        NaN   67.393581         NaN
# 24809       Shannon Whirry 1964-11-07        NaN   54.492563         NaN
# 24810           Ruth White 1914-04-24        NaN  105.034327         NaN
# 24812   Karen Malina White 1965-07-07        NaN   53.829990         NaN
# 24814          Mae Whitman 1988-06-09        NaN   30.905494         NaN
# 24815          Kym Whitley 1961-07-21        NaN   57.791741         NaN
# 24817          Mary Wickes 1910-06-13        NaN  108.897513         NaN
# 24818         Dianne Wiest 1946-03-28        NaN   73.107593         NaN
# 24819  Laura Slade Wiggins 1988-08-08        NaN   30.741220         NaN
# 24821        Collin Wilcox 1935-02-04        NaN   84.250874         NaN
# 24826        Cara Williams 1925-06-29        NaN   93.852714         NaN
# 24833       Zelda Williams 1989-07-31        NaN   29.763787         NaN
# 24835         Rumer Willis 1988-08-16        NaN   30.719317         NaN
# 24837     Elizabeth Wilson 1921-04-04        NaN   98.088256         NaN
# 24839       Kristen Wilson 1969-09-04        NaN   49.668371         NaN
#
#                                year_m                        year_div  \
# 24740                             NaN                             NaN
# 24096                             NaN  [1959, 1961, 1971, 1979, 1985]
# 16766                             NaN  [1915, 1920, 1935, 1956, 1960]
# 6888                              NaN                             NaN
# 16123                             NaN  [1915, 1920, 1935, 1956, 1960]
# 16459                             NaN  [1915, 1920, 1935, 1956, 1960]
# 6752                              NaN                             NaN
# 16291                             NaN  [1915, 1920, 1935, 1956, 1960]
# 18570                             NaN  [1980, 1988, 1992, 1997, 2003]
# 23339                             NaN  [1952, 1960, 1964, 1969, 1976]
# 4425                              NaN  [1962, 1968, 1982, 1992, 1994]
# 15728                             NaN  [1915, 1920, 1935, 1956, 1960]
# 23542                             NaN                             NaN
# 18670                             NaN  [1980, 1988, 1992, 1997, 2003]
# 24674                             NaN  [1918, 1925, 1930, 1934, 1946]
# 15796                             NaN  [1915, 1920, 1935, 1956, 1960]
# 16627                             NaN  [1915, 1920, 1935, 1956, 1960]
# 17355                             NaN                             NaN
# 17188                             NaN                             NaN
# 15955                             NaN  [1915, 1920, 1935, 1956, 1960]
# 24692                             NaN                             NaN
# 9083   [1968, 1973, 1976, 1989, 1999]        [1968, 1973, 1976, 1996]
# 9247   [1968, 1973, 1976, 1989, 1999]        [1968, 1973, 1976, 1996]
# 9413   [1968, 1973, 1976, 1989, 1999]        [1968, 1973, 1976, 1996]
# 24366  [1949, 1954, 1965, 1978, 1988]        [1953, 1963, 1975, 1981]
# 9567   [1968, 1973, 1976, 1989, 1999]        [1968, 1973, 1976, 1996]
# 9727   [1968, 1973, 1976, 1989, 1999]        [1968, 1973, 1976, 1996]
# 24470  [1929, 1934, 1943, 1953, 1961]  [1931, 1940, 1949, 1957, 1969]
# 9899   [1968, 1973, 1976, 1989, 1999]        [1968, 1973, 1976, 1996]
# 24484  [1960, 1964, 1969, 1974, 1984]        [1962, 1967, 1974, 1979]
# ...                               ...                             ...
# 24763                             NaN                             NaN
# 24767                             NaN                             NaN
# 24776                             NaN                             NaN
# 24780                             NaN                             NaN
# 24782                             NaN                             NaN
# 24783                             NaN                             NaN
# 24787                             NaN                             NaN
# 24788                             NaN                             NaN
# 24790                             NaN                             NaN
# 24791                             NaN                             NaN
# 24794                             NaN                             NaN
# 24796                             NaN                             NaN
# 24798                             NaN                             NaN
# 24802                             NaN                             NaN
# 24806                             NaN                             NaN
# 24807                             NaN                             NaN
# 24809                             NaN                             NaN
# 24810                             NaN                             NaN
# 24812                             NaN                             NaN
# 24814                             NaN                             NaN
# 24815                             NaN                             NaN
# 24817                             NaN                             NaN
# 24818                             NaN                             NaN
# 24819                             NaN                             NaN
# 24821                             NaN                             NaN
# 24826                             NaN                             NaN
# 24833                             NaN                             NaN
# 24835                             NaN                             NaN
# 24837                             NaN                             NaN
# 24839                             NaN                             NaN
#
#                             year_m_sp         year_div_sp  num_of_child_cl  \
# 24740                             NaN                 NaN              NaN
# 24096                             NaN                 NaN              NaN
# 16766                             NaN                 NaN              NaN
# 6888                              NaN                 NaN              2.0
# 16123                             NaN                 NaN              NaN
# 16459                             NaN                 NaN              NaN
# 6752                              NaN                 NaN              2.0
# 16291                             NaN                 NaN              NaN
# 18570                             NaN                 NaN              4.0
# 23339  [1942, 1951, 1953, 1959, 1965]                 NaN              3.0
# 4425         [1942, 1945, 1951, 1962]  [1942, 1949, 1962]              6.0
# 15728                             NaN                 NaN              NaN
# 23542                             NaN                 NaN              NaN
# 18670                             NaN                 NaN              4.0
# 24674                    [1916, 1924]        [1918, 1939]              3.0
# 15796                             NaN                 NaN              NaN
# 16627                             NaN                 NaN              NaN
# 17355              [1942, 1945, 1951]  [1943, 1946, 1957]             11.0
# 17188              [1942, 1945, 1951]  [1943, 1946, 1957]             11.0
# 15955                             NaN                 NaN              NaN
# 24692                    [1950, 1958]        [1951, 1965]              4.0
# 9083                              NaN                 NaN              5.0
# 9247                              NaN                 NaN              5.0
# 9413                              NaN                 NaN              5.0
# 24366                             NaN                 NaN              3.0
# 9567                              NaN                 NaN              5.0
# 9727                              NaN                 NaN              5.0
# 24470                    [1929, 1935]              [1931]              NaN
# 9899                              NaN                 NaN              5.0
# 24484                             NaN                 NaN              1.0
# ...                               ...                 ...              ...
# 24763                             NaN                 NaN              NaN
# 24767                             NaN                 NaN              NaN
# 24776                             NaN                 NaN              NaN
# 24780                             NaN                 NaN              NaN
# 24782                             NaN                 NaN              NaN
# 24783                             NaN                 NaN              4.0
# 24787                          [1995]                 NaN              1.0
# 24788                             NaN                 NaN              NaN
# 24790                             NaN                 NaN              NaN
# 24791                             NaN                 NaN              NaN
# 24794                             NaN                 NaN              1.0
# 24796                    [1963, 1969]        [1967, 1974]              1.0
# 24798                             NaN                 NaN              NaN
# 24802                             NaN                 NaN              NaN
# 24806                             NaN                 NaN              NaN
# 24807                             NaN                 NaN              NaN
# 24809                             NaN                 NaN              NaN
# 24810                             NaN                 NaN              NaN
# 24812                             NaN                 NaN              NaN
# 24814                             NaN                 NaN              NaN
# 24815                             NaN                 NaN              1.0
# 24817                             NaN                 NaN              NaN
# 24818                             NaN                 NaN              2.0
# 24819                             NaN                 NaN              NaN
# 24821                             NaN                 NaN              3.0
# 24826                             NaN                 NaN              3.0
# 24833                             NaN                 NaN              NaN
# 24835                             NaN                 NaN              NaN
# 24837                             NaN                 NaN              NaN
# 24839                             NaN                 NaN              3.0
#
#            ...       sex  divorce  age_m_1  age_div_1  age_m_sp_1  \
# 24740      ...         F      1.0      NaN        NaN         NaN
# 24096      ...         F      1.0      NaN       25.0         NaN
# 16766      ...         M      1.0      NaN       26.0         NaN
# 6888       ...         M      1.0      NaN        NaN         NaN
# 16123      ...         M      1.0      NaN       26.0         NaN
# 16459      ...         M      1.0      NaN       26.0         NaN
# 6752       ...         M      1.0      NaN        NaN         NaN
# 16291      ...         M      1.0      NaN       26.0         NaN
# 18570      ...         M      1.0      NaN       25.0         NaN
# 23339      ...         F      1.0      NaN       27.0        23.0
# 4425       ...         M      1.0      NaN       37.0        15.0
# 15728      ...         M      1.0      NaN       26.0         NaN
# 23542      ...         F      1.0      NaN        NaN         NaN
# 18670      ...         M      1.0      NaN       25.0         NaN
# 24674      ...         F      1.0      NaN       19.0        31.0
# 15796      ...         M      1.0      NaN       26.0         NaN
# 16627      ...         M      1.0      NaN       26.0         NaN
# 17355      ...         M      1.0      NaN        NaN        20.0
# 17188      ...         M      1.0      NaN        NaN        20.0
# 15955      ...         M      1.0      NaN       26.0         NaN
# 24692      ...         F      1.0      NaN        NaN         NaN
# 9083       ...         M      1.0     19.0       19.0         NaN
# 9247       ...         M      1.0     19.0       19.0         NaN
# 9413       ...         M      1.0     19.0       19.0         NaN
# 24366      ...         F      1.0     20.0       24.0         NaN
# 9567       ...         M      1.0     19.0       19.0         NaN
# 9727       ...         M      1.0     19.0       19.0         NaN
# 24470      ...         F      1.0     18.0       20.0        27.0
# 9899       ...         M      1.0     19.0       19.0         NaN
# 24484      ...         F      1.0     20.0       22.0         NaN
# ...        ...       ...      ...      ...        ...         ...
# 24763      ...         F      NaN      NaN        NaN         NaN
# 24767      ...         F      NaN      NaN        NaN         NaN
# 24776      ...         F      NaN      NaN        NaN         NaN
# 24780      ...         F      NaN      NaN        NaN         NaN
# 24782      ...         F      NaN      NaN        NaN         NaN
# 24783      ...         F      NaN      NaN        NaN         NaN
# 24787      ...         F      NaN      NaN        NaN        37.0
# 24788      ...         F      NaN      NaN        NaN         NaN
# 24790      ...         F      NaN      NaN        NaN         NaN
# 24791      ...         F      NaN      NaN        NaN         NaN
# 24794      ...         F      NaN      NaN        NaN         NaN
# 24796      ...         F      NaN      NaN        NaN        32.0
# 24798      ...         F      NaN      NaN        NaN         NaN
# 24802      ...         F      NaN      NaN        NaN         NaN
# 24806      ...         F      NaN      NaN        NaN         NaN
# 24807      ...         F      NaN      NaN        NaN         NaN
# 24809      ...         F      NaN      NaN        NaN         NaN
# 24810      ...         F      NaN      NaN        NaN         NaN
# 24812      ...         F      NaN      NaN        NaN         NaN
# 24814      ...         F      NaN      NaN        NaN         NaN
# 24815      ...         F      NaN      NaN        NaN         NaN
# 24817      ...         F      NaN      NaN        NaN         NaN
# 24818      ...         F      NaN      NaN        NaN         NaN
# 24819      ...         F      NaN      NaN        NaN         NaN
# 24821      ...         F      NaN      NaN        NaN         NaN
# 24826      ...         F      NaN      NaN        NaN         NaN
# 24833      ...         F      NaN      NaN        NaN         NaN
# 24835      ...         F      NaN      NaN        NaN         NaN
# 24837      ...         F      NaN      NaN        NaN         NaN
# 24839      ...         F      NaN      NaN        NaN         NaN
#
#       age_div_sp_1  year_m_1  year_div_1  year_m_sp_1 year_div_sp_1
# 24740          NaN       NaN         NaN          NaN           NaN
# 24096          NaN       NaN      1959.0          NaN           NaN
# 16766          NaN       NaN      1915.0          NaN           NaN
# 6888           NaN       NaN         NaN          NaN           NaN
# 16123          NaN       NaN      1915.0          NaN           NaN
# 16459          NaN       NaN      1915.0          NaN           NaN
# 6752           NaN       NaN         NaN          NaN           NaN
# 16291          NaN       NaN      1915.0          NaN           NaN
# 18570          NaN       NaN      1980.0          NaN           NaN
# 23339         23.0       NaN      1952.0       1942.0        1942.0
# 4425          15.0       NaN      1962.0       1942.0        1942.0
# 15728          NaN       NaN      1915.0          NaN           NaN
# 23542          NaN       NaN         NaN          NaN           NaN
# 18670          NaN       NaN      1980.0          NaN           NaN
# 24674         31.0       NaN      1918.0       1916.0        1916.0
# 15796          NaN       NaN      1915.0          NaN           NaN
# 16627          NaN       NaN      1915.0          NaN           NaN
# 17355         20.0       NaN         NaN       1942.0        1942.0
# 17188         20.0       NaN         NaN       1942.0        1942.0
# 15955          NaN       NaN      1915.0          NaN           NaN
# 24692          NaN       NaN         NaN       1950.0        1950.0
# 9083           NaN    1968.0      1968.0          NaN           NaN
# 9247           NaN    1968.0      1968.0          NaN           NaN
# 9413           NaN    1968.0      1968.0          NaN           NaN
# 24366          NaN    1949.0      1953.0          NaN           NaN
# 9567           NaN    1968.0      1968.0          NaN           NaN
# 9727           NaN    1968.0      1968.0          NaN           NaN
# 24470         27.0    1929.0      1931.0       1929.0        1929.0
# 9899           NaN    1968.0      1968.0          NaN           NaN
# 24484          NaN    1960.0      1962.0          NaN           NaN
# ...            ...       ...         ...          ...           ...
# 24763          NaN       NaN         NaN          NaN           NaN
# 24767          NaN       NaN         NaN          NaN           NaN
# 24776          NaN       NaN         NaN          NaN           NaN
# 24780          NaN       NaN         NaN          NaN           NaN
# 24782          NaN       NaN         NaN          NaN           NaN
# 24783          NaN       NaN         NaN          NaN           NaN
# 24787         37.0       NaN         NaN       1995.0        1995.0
# 24788          NaN       NaN         NaN          NaN           NaN
# 24790          NaN       NaN         NaN          NaN           NaN
# 24791          NaN       NaN         NaN          NaN           NaN
# 24794          NaN       NaN         NaN          NaN           NaN
# 24796         32.0       NaN         NaN       1963.0        1963.0
# 24798          NaN       NaN         NaN          NaN           NaN
# 24802          NaN       NaN         NaN          NaN           NaN
# 24806          NaN       NaN         NaN          NaN           NaN
# 24807          NaN       NaN         NaN          NaN           NaN
# 24809          NaN       NaN         NaN          NaN           NaN
# 24810          NaN       NaN         NaN          NaN           NaN
# 24812          NaN       NaN         NaN          NaN           NaN
# 24814          NaN       NaN         NaN          NaN           NaN
# 24815          NaN       NaN         NaN          NaN           NaN
# 24817          NaN       NaN         NaN          NaN           NaN
# 24818          NaN       NaN         NaN          NaN           NaN
# 24819          NaN       NaN         NaN          NaN           NaN
# 24821          NaN       NaN         NaN          NaN           NaN
# 24826          NaN       NaN         NaN          NaN           NaN
# 24833          NaN       NaN         NaN          NaN           NaN
# 24835          NaN       NaN         NaN          NaN           NaN
# 24837          NaN       NaN         NaN          NaN           NaN
# 24839          NaN       NaN         NaN          NaN           NaN
#
# [24840 rows x 29 columns]

# %%
# calculate the divorce rate
(df['divorce'].value_counts()/df['divorce'].notnull().sum()).plot(kind="bar")
plt.title("divoice rate (include male and female)");

# %%
#fig = plt.figure(figsize = (15,20))
#ax = fig.gca()
df_div_rm.hist(figsize=(15,12));

# %%
fig, ax = plt.subplots(figsize=(12,12))         # Sample figsize in inches
sns.heatmap(df_div_rm.corr(), annot=True, fmt=".2f");

# %% [markdown]
# ### deal with missing data
# Remove the rows associated with nan values in divorce column. Store the dataframe with these rows removed in df_div_rm.

# %%
df_div_rm = df.dropna(axis = 0, subset=["divorce"])# dataframe with rows for nan divorce removed
df_div_rm.head()
# Out:
#              name       bday  age_diff        age  age_spouse  \
# 2    Willie Aames 1960-07-15       NaN  58.810243         NaN
# 5    Bruce Abbott 1954-07-28 -2.165684  64.776142   62.610457
# 6      Bud Abbott        NaT       NaN        NaN         NaN
# 8   Philip Abbott        NaT       NaN        NaN         NaN
# 10      Jake Abel 1987-11-18       NaN  31.466765         NaN
#
#                 year_m year_div     year_m_sp   year_div_sp  num_of_child_cl  \
# 2   [1979, 1986, 2014]      NaN           NaN           NaN              2.0
# 5         [1982, 1994]   [1989]  [1982, 1997]  [1989, 1999]              2.0
# 6               [1918]      NaN           NaN           NaN              2.0
# 8               [1950]      NaN           NaN           NaN              NaN
# 10              [2013]      NaN           NaN           NaN              NaN
#
#        ...       geohash  geo_distance   zodiac  zodiac_sp  sex divorce  \
# 2      ...       9mupk2n            NaN     6.0        NaN    M     1.0
# 5      ...       c20fbmg     20000000.0     7.0        9.0    M     1.0
# 6      ...       dr5kgcf            NaN     NaN        NaN    M     0.0
# 8      ...       9z70pmz            NaN     NaN        NaN    M     1.0
# 10     ...       dpq0h5n            NaN    10.0        NaN    M     0.0
#
#     age_m_1  age_div_1  age_m_sp_1 age_div_sp_1
# 2      19.0        NaN         NaN          NaN
# 5      28.0       35.0        26.0         26.0
# 6       NaN        NaN         NaN          NaN
# 8       NaN        NaN         NaN          NaN
# 10     26.0        NaN         NaN          NaN
#
# [5 rows x 25 columns]

# %%
(df_div_rm.isnull().sum()/len(df_div_rm)*100).sort_values()
# Out:
# name                   0.000000
# sex                    0.000000
# num_of_m               0.000000
# divorce                0.000000
# year_m                 0.313059
# geohash                1.132976
# bday                   2.683363
# age                    2.683363
# zodiac                 2.683363
# age_m_1                2.996422
# num_of_role            3.905784
# num_of_child_cl       33.452594
# year_div              58.273703
# age_div_1             59.138342
# geo_distance          69.692904
# age_spouse            70.885510
# zodiac_sp             70.885510
# num_of_role_sp        71.377460
# age_diff              71.407275
# num_of_m_sp           74.045915
# year_m_sp             74.299344
# age_m_sp_1            75.864639
# age_div_sp_1          75.864639
# num_of_child_sp_cl    79.651163
# year_div_sp           85.763268
# dtype: float64

# %% [markdown]
# # Conclusions and Next Steps
# Summarize findings here

# %%
import pandas as pd
df = pd.read_csv('export_df_actress.csv')
